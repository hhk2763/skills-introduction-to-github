# %% [markdown]
# <a href="https://colab.research.google.com/github/hhk2763/skills-introduction-to-github/blob/main/yolo_fork_lifter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install ultralytics
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.6/873.6 kB 24.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.0
#     Uninstalling ultralytics-8.0.0:
#       Successfully uninstalled ultralytics-8.0.0
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="BMqTUfGLhPVBYhyzkj3m")
project = rf.workspace("mohamed-traore-2ekkp").project("forklift-dsitv")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.0, to fix: `pip install ultralytics==8.0.196`

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/Forklift-5/data.yaml epochs=50
# Out:
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
